# %%
from ydata_profiling import ProfileReport
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("Tunisair_flights_dataset.csv")

# %%
df.head()
# Out:
#   Filght_date Flight_ID Departure point Arrival point  \
# 0  2016-01-03  TU 0712              CMN           TUN
# 1  2016-01-13  TU 0757              MXP           TUN
# 2  2016-01-16  TU 0214              TUN           IST
# 3  2016-01-17  TU 0480              DJE           NTE
# 4  2016-01-17  TU 0338              TUN           ALG
#
#   Scheduled_departure_time Scheduled_arrival_time STATUS Aircraft_code  \
# 0      2016-01-03 10:30:00    2016-01-03 12.55.00    ATA     TU 32AIMN
# 1      2016-01-13 15:05:00    2016-01-13 16.55.00    ATA     TU 31BIMO
# 2      2016-01-16 04:10:00    2016-01-16 06.45.00    ATA     TU 32AIMN
# 3      2016-01-17 14:10:00    2016-01-17 17.00.00    ATA     TU 736IOK
# 4      2016-01-17 14:30:00    2016-01-17 15.50.00    ATA     TU 320IMU
#
#    Arrival delay
# 0          260.0
# 1           20.0
# 2            0.0
# 3            0.0
# 4           22.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107833 entries, 0 to 107832
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Filght_date               107833 non-null  object
#  1   Flight_ID                 107833 non-null  object
#  2   Departure point           107833 non-null  object
#  3   Arrival point             107833 non-null  object
#  4   Scheduled_departure_time  107833 non-null  object
#  5   Scheduled_arrival_time    107833 non-null  object
#  6   STATUS                    107833 non-null  object
#  7   Aircraft_code             107833 non-null  object
#  8   Arrival delay             107833 non-null  float64
# dtypes: float64(1), object(8)
# memory usage: 7.4+ MB

# %%
df.isnull().sum()
# Out:
# Filght_date                 0
# Flight_ID                   0
# Departure point             0
# Arrival point               0
# Scheduled_departure_time    0
# Scheduled_arrival_time      0
# STATUS                      0
# Aircraft_code               0
# Arrival delay               0
# dtype: int64

# %%
df.describe()
# Out:
#        Arrival delay
# count  107833.000000
# mean       48.733013
# std       117.135562
# min         0.000000
# 25%         0.000000
# 50%        14.000000
# 75%        43.000000
# max      3451.000000

# %%
#create a variable to store the report
profile = ProfileReport(df, title="Tunisair Profiling")

profile
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# %|                                                                                            | 0/9 [00:00<?, ?it/s]
# %|█████████▎                                                                          | 1/9 [00:01<00:12,  1.56s/it]
# %|██████████████████▋                                                                 | 2/9 [00:01<00:05,  1.31it/s]
# %|████████████████████████████                                                        | 3/9 [00:01<00:02,  2.14it/s]
# %|██████████████████████████████████████████████▋                                     | 5/9 [00:02<00:01,  2.93it/s]
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %% [markdown]
# # Write a summary of your findings. Did you find any interesting patterns or correlations in the data?
# # Were there any issues or challenges you encountered while exploring the dataset?
# # Use your summary to reflect on your experience using pandas and ydata-profiling to explore and understand a new dataset.
#
# -Key Observations
# 1. The dataset has over 100,000 flight records.
#
# 2. The main focus is on arrival delays.
#
# 3. Average delay is around 49 minutes.
#
# 4. Most flights have 0 delay, meaning they arrived on time.
#
# 5. However, some delays are very long, which increases the average and spread.
#
# - Data Issues Noticed
# 1. Some columns have missing data.
#
# 2. Many flights show 0 delay, which may either mean on-time or missing/incorrect data.
#
# 3. There's only one main numeric column (Arrival delay), so more columns may need to be converted to numbers for deeper analysis.
#
# - Patterns Found
# No major correlations found yet due to lack of numeric columns.
#
# Delay times are very inconsistent, with many being on time and others being heavily delayed.
#
# - Using Pandas and ydata-profiling helped me quickly understand data structure, spot missing values, detect trends, and identify outliers—making data exploration faster, clearer, and more insightful.
